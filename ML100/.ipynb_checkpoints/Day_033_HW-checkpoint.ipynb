# %% [markdown]
# ## 練習時間

# %% [markdown]
# 請觀看李宏毅教授以神奇寶貝進化 CP 值預測的範例，解說何謂機器學習與過擬合。並回答以下問題

# %% [markdown]
# [youtube](https://www.youtube.com/watch?v=fegAeph9UaA)

# %% [markdown]
# ### 1. 模型的泛化能力 (generalization) 是指什麼？
# ### 2. 分類問題與回歸問題分別可用的目標函數有哪些？

# %% [markdown]
# # Ans
#
# ## 1. 模型的泛化能力 (generalization) 是指模型很好地擬合以前未見過的新數據的能力。也就是舉一反三的能力，或者叫做學以致用的能力。
#
#
# ## 2. 分類問題與回歸問題分別可用的目標函數有哪些？
#
# ![classification_regression_errors.png](attachment:classification_regression_errors.png)
#
# ### 2.1 常見的分類問題可用的目標函數
# #### 2.1.1 Logistic loss
# logistic Loss為Logistic Regression中使用的損失函數
# ![log_loss.svg](attachment:log_loss.svg)
# 上式被稱為交叉熵損失 (cross entropy loss)，可以看到在二分類問題中 logistic loss 和交叉熵損失是等價的，二者區別只是標籤 y 的定義不同。
#
#
# ### 2.2 常見的回歸問題可用的目標函數
# #### 2.2.1 平均絕對值誤差（也稱 L1 損失）
# ![mean_absolute_error_L1.jpg](attachment:mean_absolute_error_L1.jpg)
#
# #### 2.2.2 均方誤差（也稱 L1 損失）
# ![mean_sqare_error.jpg](attachment:mean_sqare_error.jpg)
